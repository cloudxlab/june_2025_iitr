# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([2,-1,3,5])

# %% [raw]
# Data (Files/ Database)
#     -> pd.Dataframe
#         --> drop columns, adding columns, filter (cleaning / massaging) - Pandas ->
#             --> numpy
#                 --> numeric operationals
#                 -----> machine learning using (sklearn)
#                 and / or
#                 -----> tensorflow / pytorch
#
# # Pandas -> numpy -> sklearn / pytorch / tensorflow

# %%
s
# Out:
# 0    2
# 1   -1
# 2    3
# 3    5
# dtype: int64

# %%
np.square(s)
# Out:
# 0     4
# 1     1
# 2     9
# 3    25
# dtype: int64

# %%
s + [1000,2000,3000,4000]
# Out:
# 0    1002
# 1    1999
# 2    3003
# 3    4005
# dtype: int64

# %%
s + 1000
# Out:
# 0    1002
# 1     999
# 2    1003
# 3    1005
# dtype: int64

# %%
s < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s1 = pd.Series([68, 83, 112, 68])
print(s1)
# Out:
# 0     68
# 1     83
# 2    112
# 3     68
# dtype: int64

# %%
s2 = pd.Series([68, 83, 112, 68],    index=["alice", "bob", "charles", "darwin"])

# %%
s2
# Out:
# alice       68
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %%
s2[-1]
# Out:
# /var/folders/xg/0b5tly_55_v3g39k5qx0jc580000gn/T/ipykernel_34451/3032101855.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2[-1]
# np.int64(68)

# %%
s2["bob"]
# Out:
# np.int64(83)

# %%
s2[1:]
# Out:
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %%
s2.loc["bob"]
# Out:
# np.int64(83)

# %%
s2.iloc[-1]
# Out:
# np.int64(68)

# %%
weights = {"alice": 68, "bob": 83, "colin": 86, "darwin": 68}
s3 = pd.Series(weights)

# %%
s3
# Out:
# alice     68
# bob       83
# colin     86
# darwin    68
# dtype: int64

# %%
s4 = pd.Series(weights, index = ["colin", "alice"])

# %%
s4
# Out:
# colin    86
# alice    68
# dtype: int64

# %%
s2
# Out:
# alice       68
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %%
s3
# Out:
# alice     68
# bob       83
# colin     86
# darwin    68
# dtype: int64

# %%
s2 + s3
# Out:
# alice      136.0
# bob        166.0
# charles      NaN
# colin        NaN
# darwin     136.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
temperatures = [4.4,5.1,6.1,6.2,6.1,6.1,5.7,5.2,4.7,4.1,3.9,3.5]
s7 = pd.Series(temperatures, name="Temperature")

# %%
s7.plot()
# Out:
# <Axes: >

# %%
s7
# Out:
# 0     4.4
# 1     5.1
# 2     6.1
# 3     6.2
# 4     6.1
# 5     6.1
# 6     5.7
# 7     5.2
# 8     4.7
# 9     4.1
# 10    3.9
# 11    3.5
# Name: Temperature, dtype: float64

# %%
people_dict = {
    "weight": pd.Series([68, 83, 112],          index=["alice", "bob", "charles"]),
    "birthyear": pd.Series([1984, 1985, 1992],  index=["bob", "alice", "charles"], name="year"),
    "children": pd.Series([0, 3],               index=["charles", "bob",]),
    "hobby": pd.Series(["Biking", "Dancing"],   index=["alice", "bob"]),
}
people = pd.DataFrame(people_dict)

people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people.index
# Out:
# Index(['alice', 'bob', 'charles'], dtype='object')

# %%
people.columns
# Out:
# Index(['weight', 'birthyear', 'children', 'hobby'], dtype='object')

# %%
b = people['birthyear']

# %%
b
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people.loc['bob']
# Out:
# weight            83
# birthyear       1984
# children         3.0
# hobby        Dancing
# Name: bob, dtype: object

# %%
people['birthyear']['bob']
# Out:
# np.int64(1984)

# %%
people['bob']['birthyear']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/june_2025_iitr/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bob'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ...

# %%
people[['weight', 'birthyear']]
# Out:
#          weight  birthyear
# alice        68       1985
# bob          83       1984
# charles     112       1992

# %%
people[people['weight'] > 100]
# Out:
#          weight  birthyear  children hobby
# charles     112       1992       0.0   NaN

# %%
people['weight'] > 100
# Out:
# alice      False
# bob        False
# charles     True
# Name: weight, dtype: bool

# %%
people['weight'] < 80
# Out:
# alice       True
# bob        False
# charles    False
# Name: weight, dtype: bool

# %%
people[(people['weight'] > 100) | (people['weight'] < 80)]
# Out:
#          weight  birthyear  children   hobby
# alice        68       1985       NaN  Biking
# charles     112       1992       0.0     NaN

# %%
people[((people['weight'] > 100) | (people['weight'] < 80)) & (people['hobby'] == 'Biking')]
# Out:
#        weight  birthyear  children   hobby
# alice      68       1985       NaN  Biking

# %%
people.iloc[1:3]
# Out:
#          weight  birthyear  children    hobby
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people[['weight', 'birthyear']]
# Out:
#          weight  birthyear
# alice        68       1985
# bob          83       1984
# charles     112       1992

# %%
people[[True, False, False]]
# Out:
#        weight  birthyear  children   hobby
# alice      68       1985       NaN  Biking

# %%
2025 - people["birthyear"]
# Out:
# alice      40
# bob        41
# charles    33
# Name: birthyear, dtype: int64

# %%
people["age"] = 2025 - people["birthyear"]
people
# Out:
#          weight  birthyear  children    hobby  age
# alice        68       1985       NaN   Biking   40
# bob          83       1984       3.0  Dancing   41
# charles     112       1992       0.0      NaN   33

# %%
people["over 30"] = people["age"] > 30

# %%
people
# Out:
#          weight  birthyear  children    hobby  age  over 30
# alice        68       1985       NaN   Biking   40    False
# bob          83       1984       3.0  Dancing   41     True
# charles     112       1992       0.0      NaN   33    False

# %%
people["over 40"] = people["age"] > 40

# %%
people
# Out:
#          weight  birthyear  children    hobby  age  over 30  over 40
# alice        68       1985       NaN   Biking   40     True    False
# bob          83       1984       3.0  Dancing   41     True     True
# charles     112       1992       0.0      NaN   33     True    False

# %%
people.pop('over 30')
# Out:
# alice      True
# bob        True
# charles    True
# Name: over 30, dtype: bool

# %%
people
# Out:
#          weight  birthyear  children    hobby  age  over 40
# alice        68       1985       NaN   Biking   40    False
# bob          83       1984       3.0  Dancing   41     True
# charles     112       1992       0.0      NaN   33    False

# %%
del people['over 40']

# %%
people
# Out:
#          weight  birthyear  children    hobby  age
# alice        68       1985       NaN   Biking   40
# bob          83       1984       3.0  Dancing   41
# charles     112       1992       0.0      NaN   33

# %%
people
# Out:
#          weight  birthyear  children    hobby  age
# alice        68       1985       NaN   Biking   40
# bob          83       1984       3.0  Dancing   41
# charles     112       1992       0.0      NaN   33

# %%
people["pets"] = pd.Series({
"bob": 0, 
"charles": 5,
"eugene":1
})

# %%
people
# Out:
#          weight  birthyear  children    hobby  age  pets
# alice        68       1985       NaN   Biking   40   NaN
# bob          83       1984       3.0  Dancing   41   0.0
# charles     112       1992       0.0      NaN   33   5.0

# %%
people.insert(1, "height", [172, 181, 185])

# %%
people
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# alice        68     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0

# %%
people_new = people.assign(body_mass_index = lambda df:df["weight"] / (df["height"] / 100) ** 2)

# %%
people['body_mass_index'] = people["weight"] / (people["height"] / 100) ** 2

# %%
people_new
# Out:
#          weight  height  birthyear  children    hobby  age  pets  \
# alice        68     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0
#
#          body_mass_index
# alice          22.985398
# bob            25.335002
# charles        32.724617

# %%
people_new.assign(overweight = lambda df:	 df["body_mass_index"] > 25)
# Out:
#          weight  height  birthyear  children    hobby  age  pets  \
# alice        68     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0
#
#          body_mass_index  overweight
# alice          22.985398       False
# bob            25.335002        True
# charles        32.724617        True

# %%
people.loc['alice', 'weight'] = 200

# %%
people
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# alice       200     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0

# %%
people_new
# Out:
#          weight  height  birthyear  children    hobby  age  pets  \
# alice       100     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0
#
#          body_mass_index
# alice          22.985398
# bob            25.335002
# charles        32.724617

# %%
people_new.loc['alice', 'weight'] = 150

# %%
people_new
# Out:
#          weight  height  birthyear  children    hobby  age  pets  \
# alice       150     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0
#
#          body_mass_index
# alice          22.985398
# bob            25.335002
# charles        32.724617

# %%
people
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# alice       200     172       1985       NaN   Biking   40   NaN
# bob          83     181       1984       3.0  Dancing   41   0.0
# charles     112     185       1992       0.0      NaN   33   5.0

# %%
people.sort_index(ascending=False)
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# charles     112     185       1992       0.0      NaN   33   5.0
# bob          83     181       1984       3.0  Dancing   41   0.0
# alice       200     172       1985       NaN   Biking   40   NaN

# %%
people.sort_index(inplace=True, ascending=False)

# %%
people
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# charles     112     185       1992       0.0      NaN   33   5.0
# bob          83     181       1984       3.0  Dancing   41   0.0
# alice       200     172       1985       NaN   Biking   40   NaN

# %%
people.loc['alice', 'weight'] = 112
people
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# charles     112     185       1992       0.0      NaN   33   5.0
# bob          83     181       1984       3.0  Dancing   41   0.0
# alice       112     172       1985       NaN   Biking   40   NaN

# %%
people.sort_values(['weight', 'height'])
# Out:
#          weight  height  birthyear  children    hobby  age  pets
# bob          83     181       1984       3.0  Dancing   41   0.0
# alice       112     172       1985       NaN   Biking   40   NaN
# charles     112     185       1992       0.0      NaN   33   5.0

# %%
people_new.plot(
kind = "line", 
x = "body_mass_index", 
y = ["height", "weight"]
)
# Out:
# <Axes: xlabel='body_mass_index'>

# %% [markdown]
# # Exercise
#
# On kaggle find a good dataset and download it and load it as pandas dataframe.
# And try downing basic visualization

# %% [markdown]
# # https://www.kaggle.com/datasets/ellimaaac/gpus-specs-from-1986-to-2026?resource=download

# %%
# !ls gpu*
# Out:
# gpu_1986-2026.csv

# %%
pd.read_csv('gpu_1986-2026.csv')
# Out:
#      Brand                      Name Top__GRAPHICS PROCESSOR  \
# 0      ATI      Color Emulation Card               CW16800-A
# 1      ATI         Graphics Solution               CW16800-A
# 2      ATI            EGA Wonder 800                 16899-0
# 3      ATI    Graphics Solution Plus               CW16800-B
# 4      ATI  VGA Improved Performance                 16899-0
# ...    ...                       ...                     ...
# 3198   XGI           Volari V5 Ultra                    XG41
# 3199   XGI                 Volari V8                    XG40
# 3200   XGI                 Volari V8                    XG40
# 3201   XGI           Volari V8 Ultra                    XG40
# 3202   XGI           Volari V8 Ultra                    XG40
#
#      Top__PIXEL SHADERS Top__VERTEX SHADERS Top__TMUS Top__ROPS  \
# 0                   NaN                 NaN       NaN       NaN
# 1                   NaN                 NaN       NaN       NaN
# ...

# %%
my_df = pd.DataFrame(
    	[
["Biking", 68.5, 1985, np.nan],
["Dancing", 83.1, 1984, 3]
], 
    columns=["hobby","weight","birthyear","children"],
    index=["alice", "bob"]
)
my_df
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
my_df.to_csv("my_df.csv")

# %%
# !ls *.csv
# Out:
# gpu_1986-2026.csv movie_reviews.csv my_df.csv

# %%
my_df.to_html("my_df.html")

# %%
# !ls *.html
# Out:
# my_df.html

# %%
# !cat my_df.html
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hobby</th>
#       <th>weight</th>
#       <th>birthyear</th>
#       <th>children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alice</th>
#       <td>Biking</td>
#       <td>68.5</td>
#       <td>1985</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>bob</th>
#       <td>Dancing</td>
#       <td>83.1</td>
#       <td>1984</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
my_df.to_json("my_df.json")

# %%
# !cat my_df.json
# Out:
# {"hobby":{"alice":"Biking","bob":"Dancing"},"weight":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"children":{"alice":null,"bob":3.0}}

# %%
from pprint import pprint

# %%
pprint(open('my_df.json').read()
)
# Out:
# '{"hobby":{"alice":"Biking","bob":"Dancing"},"weight":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"children":{"alice":null,"bob":3.0}}'

# %%
housing = pd.read_csv('housing.csv')

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
housing.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing[housing['total_bedrooms'].isna()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df1 = housing[['longitude',	'latitude',	'housing_median_age',	'total_rooms', 'total_bedrooms',	'population',	'households',	'median_income'	,'median_house_value'	]]

# %%
df1.corr() # covariance
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
A | A - mean()| B | B - mean(B) | Mult
1 |-0.5       | 2 | -1          | .5
2 |..5        | 4 | +1          | .5

1

# %%
df = pd.DataFrame({
    'A': pd.Series([1, 2, 3]),
    'B': pd.Series([2, 2, 2.2])
})
df
# Out:
#    A    B
# 0  1  2.0
# 1  2  2.0
# 2  3  2.2

# %%
df.corr()
# Out:
#           A         B
# A  1.000000  0.866025
# B  0.866025  1.000000

# %%
pd.read_sql?
# Out:
# Signature:
# pd.read_sql(
#     sql,
#     con,
#     index_col: 'str | list[str] | None' = None,
#     coerce_float: 'bool' = True,
#     params=None,
#     parse_dates=None,
#     columns: 'list[str] | None' = None,
#     chunksize: 'int | None' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
#     dtype: 'DtypeArg | None' = None,
# ) -> 'DataFrame | Iterator[DataFrame]'
# Docstring:
# Read SQL query or database table into a DataFrame.
#
# This function is a convenience wrapper around ``read_sql_table`` and
# ``read_sql_query`` (for backward compatibility). It will delegate
# to the specific function depending on the provided input. A SQL query
# will be routed to ``read_sql_query``, while a database table name will
# be routed to ``read_sql_table``. Note that the delegated function might
# have more specific notes about their functionality not listed here.
#
# Parameters
# ----------
# sql : str or SQLAlchemy Selectable (select or text object)
# ...

# %%
# Connect to data source
SQLAlchemy
