# %% [raw]
# Exercises:
#
# # 1
# 1. Based on new_groups data build an embeddings based model and observe the various metrics. Checkout '52_natural_language_processing_classical_approach.ipynb'
#
# # 2 - Predict next character
#
# 2. Break down shakespear.txt into sliding windows
#     50 letters (X) -> next letter (y)
# 3. translate each letter into one hot encoding in X
# a = [1, 0, 0, 0, 0 ...]
# b = [0, 1, 0, 0, 0 ...]
# c = [....]
#
# 4. y - convert it into ids. Multiclass classification.
# 5. Use a deep neural network to do this.
