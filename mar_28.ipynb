# %%
# Computation can be represented as a tree

Node:
    - type: "op" / "val"
    - val: "+", "-", 0-9, ...
    - left
    - right
    def eval():
        if type != 'op':
            return val
        else:
            l = left.eval()
            r = right.eval()
            if op == '+':
                return l + r
            if op == '-':
                return l - r
            if op == '*':
                return l * r
            if opn == '/':
                return l / r

# %% [raw]
# # Parsing:
# - Try parsing a simple expression - 2 * (4*6 + 7) to create a tree
# - Learn about recursive parsing: (https://chatgpt.com/share/69c74842-4e1c-8329-894b-245e86f837d7)
#         expression : exp1 +/- exp1
#         exp1 : exp2 * exp2
#         exp2 : exp3 ^ exp3
#         exp3 : atom or (expression)
# - K & R - 5.12
# - https://www.antlr.org/
#         - compiler compilers
#                 - yacc
#                 - javac

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Expression -> Tree

# %% [markdown]
# https://chatgpt.com/share/69c74842-4e1c-8329-894b-245e86f837d7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Exercise - 1:
#
# - For this computation graph
#
# y1  = step_function(w11 * x + w10)
# y2 = sigmoid(y1*w21 + w20)
# y3 = x * y2
# y = w31 * y3 + w30
#
# Choose some values of ws, plot y vs x
# choose some other values of ws, plot y vs x

# %% [raw]
# Exercise - 2:
#
# - Come up with your random ideas of computation graph as above
#
# Choose some values of ws, plot y vs x
# choose some other values of ws, plot y vs x

# %% [raw]
# # Code our backprop
#
# - test if we can some up with a neural network for Square, cube or cube root
