# %%
import numpy as np

# %%
result = [.49, .1, .1, .1, .1]

# %%
arr = np.array([.1, .9])

# if numbers are less .5 divide by 10 else leave it as such

result = (10*arr)**2

result = result/sum(result)
result
# Out:
# array([0.01219512, 0.98780488])

# %%
arr = np.array([.1,.1,.1, .49, .04, .17])

# if numbers are less .5 divide by 10 else leave it as such
T = .1
result = (arr)**(1/T)
result = result/sum(result)
result
# Out:
# array([1.25322215e-07, 1.25322215e-07, 1.25322215e-07, 9.99974359e-01,
#        1.31409867e-11, 2.52648822e-05])

# %%
# # Incorporate these two ideas into your beam search:
# - picking words based on likelihood instead of only top
# - Tweaking the probability based on the temperature
