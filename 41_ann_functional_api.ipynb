# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

# TensorFlow ≥2.0 is required
import tensorflow as tf
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "ann"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing() # loading the California Housing dataset

X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42) # test and train
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42) # training and validation

# Using the StandardScaler to scale the dataset

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
# Defining the layers

input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_, hidden2]) # concatenate inputs
output = keras.layers.Dense(1)(concat)

model = keras.models.Model(inputs=[input_], outputs=[output])

# %%
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3)) # compile model

# %%
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid)) # fit model
# Out:
# Epoch 1/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.3369 - val_loss: 0.3627
# Epoch 2/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 0.3363 - val_loss: 0.3954
# Epoch 3/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.3362 - val_loss: 0.3360
# Epoch 4/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 0.3359 - val_loss: 0.3578
# Epoch 5/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 0.3355 - val_loss: 0.3628
# Epoch 6/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.3354 - val_loss: 0.3333
# Epoch 7/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.3348 - val_loss: 0.3401
# Epoch 8/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.3349 - val_loss: 0.3599
# Epoch 9/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 0.3345 - val_loss: 0.3256
# Epoch 10/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.3341 - val_loss: 0.3792
# Epoch 11/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 0.3338 - val_loss: 0.3200
# Epoch 12/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 0.3336 - val_loss: 0.4075
# Epoch 13/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.3336 - val_loss: 0.3303
# Epoch 14/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 0.3330 - val_loss: 0.3914
# Epoch 15/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 0.3328 - val_loss: 0.3590
# Epoch 16/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 0.3324 - val_loss: 0.3183
# Epoch 17/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 0.3322 - val_loss: 0.3379
# Epoch 18/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 0.3319 - val_loss: 0.4044
# Epoch 19/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 0.3316 - val_loss: 0.3256
# Epoch 20/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.3310 - val_loss: 0.4256
# Epoch 21/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 0.3316 - val_loss: 0.3174
# Epoch 22/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.3308 - val_loss: 0.3313
# Epoch 23/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.3306 - val_loss: 0.3527
# Epoch 24/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.3304 - val_loss: 0.3442
# Epoch 25/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.3298 - val_loss: 0.3807
# Epoch 26/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.3298 - val_loss: 0.3719
# Epoch 27/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3294 - val_loss: 0.3491
# Epoch 28/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3291 - val_loss: 0.3299
# Epoch 29/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3287 - val_loss: 0.3721
# Epoch 30/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3288 - val_loss: 0.3445
# Epoch 31/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3285 - val_loss: 0.3551
# Epoch 32/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3279 - val_loss: 0.3256
# Epoch 33/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3277 - val_loss: 0.3666
# Epoch 34/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3279 - val_loss: 0.3319
# Epoch 35/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3274 - val_loss: 0.3395
# Epoch 36/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3270 - val_loss: 0.3942
# Epoch 37/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3269 - val_loss: 0.3668
# Epoch 38/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3267 - val_loss: 0.3871
# Epoch 39/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3266 - val_loss: 0.3159
# Epoch 40/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3261 - val_loss: 0.3578
# Epoch 41/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3259 - val_loss: 0.3611
# Epoch 42/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3258 - val_loss: 0.3165
# Epoch 43/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3256 - val_loss: 0.3437
# Epoch 44/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3253 - val_loss: 0.3262
# Epoch 45/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3250 - val_loss: 0.3243
# Epoch 46/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3249 - val_loss: 0.3786
# Epoch 47/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3247 - val_loss: 0.3442
# Epoch 48/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3242 - val_loss: 0.3129
# Epoch 49/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3241 - val_loss: 0.3353
# Epoch 50/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3237 - val_loss: 0.3784
# Epoch 51/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3236 - val_loss: 0.3431
# Epoch 52/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3234 - val_loss: 0.3141
# Epoch 53/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3232 - val_loss: 0.3614
# Epoch 54/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3231 - val_loss: 0.3166
# Epoch 55/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3226 - val_loss: 0.3145
# Epoch 56/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3224 - val_loss: 0.3861
# Epoch 57/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3225 - val_loss: 0.3368
# Epoch 58/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3219 - val_loss: 0.3767
# Epoch 59/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.3222 - val_loss: 0.3281
# Epoch 60/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.3217 - val_loss: 0.3184
# Epoch 61/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 0.3217 - val_loss: 0.3458
# Epoch 62/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.3213 - val_loss: 0.3513
# Epoch 63/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.3213 - val_loss: 0.3342
# Epoch 64/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.3208 - val_loss: 0.3646
# Epoch 65/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.3207 - val_loss: 0.3284
# Epoch 66/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.3200 - val_loss: 0.3753
# Epoch 67/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.3205 - val_loss: 0.3248
# Epoch 68/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.3199 - val_loss: 0.3191
# Epoch 69/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.3200 - val_loss: 0.3220
# Epoch 70/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.3195 - val_loss: 0.3316
# Epoch 71/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.3194 - val_loss: 0.3715
# Epoch 72/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.3195 - val_loss: 0.3249
# Epoch 73/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 0.3191 - val_loss: 0.3292
# Epoch 74/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.3191 - val_loss: 0.3088
# Epoch 75/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: 0.3188 - val_loss: 0.3215
# Epoch 76/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 0.3184 - val_loss: 0.3733
# Epoch 77/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 0.3186 - val_loss: 0.3155
# Epoch 78/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.3179 - val_loss: 0.3653
# Epoch 79/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.3181 - val_loss: 0.3093
# Epoch 80/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.3177 - val_loss: 0.3387
# Epoch 81/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 0.3173 - val_loss: 0.3091
# Epoch 82/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - loss: 0.3173 - val_loss: 0.3354
# Epoch 83/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.3172 - val_loss: 0.3500
# Epoch 84/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.3169 - val_loss: 0.3214
# Epoch 85/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.3167 - val_loss: 0.3107
# Epoch 86/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.3165 - val_loss: 0.3629
# Epoch 87/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.3164 - val_loss: 0.3513
# Epoch 88/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.3161 - val_loss: 0.3146
# Epoch 89/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.3160 - val_loss: 0.3321
# Epoch 90/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.3157 - val_loss: 0.3469
# Epoch 91/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.3154 - val_loss: 0.3079
# Epoch 92/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.3151 - val_loss: 0.4170
# Epoch 93/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.3156 - val_loss: 0.3222
# Epoch 94/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.3153 - val_loss: 0.4316
# Epoch 95/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.3155 - val_loss: 0.3128
# Epoch 96/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.3146 - val_loss: 0.3947
# Epoch 97/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.3147 - val_loss: 0.3071
# Epoch 98/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.3144 - val_loss: 0.3455
# Epoch 99/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.3143 - val_loss: 0.3123
# Epoch 100/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.3138 - val_loss: 0.3431

# %%
mse_test = model.evaluate(X_test, y_test) # evaluate model
mse_test
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 0.3389
# 0.3388998210430145

# %%
y_pred = model.predict(X_test) # predict using the model

# %%
type(input_)
# Out:
# keras.src.backend.common.keras_tensor.KerasTensor

# %%
type(hidden1)
# Out:
# keras.src.backend.common.keras_tensor.KerasTensor

# %%
# hidden1 = keras.layers.Dense(30, activation="relu")(input_)

f = keras.layers.Dense(30, activation="relu")
hidden1 = f(input_)

# %%
type(f)
# Out:
# keras.src.layers.core.dense.Dense

# %%
# I want to create a function that build another function that does the power

sq = power_builder(2)
sq(2) # 4
sq(3) # 9

mycube = power_builder(3)
mycube(2) # 8
mycube(3) # 27


mysqrt = power_builder(.5)
mysqrt(4) # 2
mycube(16) # 4

# %%
# Closures!
def power_builder(p):
    def f(x):
        return x**p #math.power(x, p)
    return f

# %%
sq = power_builder(2)
sq(2), sq(3)

# def sq(x):
#     return x**2 #math.power(x, p)
# Out:
# (4, 9)

# %%
mycube = power_builder(3)
mycube(2), mycube(3)

# def mycube(x):
#     return x**3 #math.power(x, p)
# Out:
# (8, 27)

# %%
mysqrt = power_builder(.5)
mysqrt(4), mysqrt(16)
# Out:
# (2.0, 4.0)
