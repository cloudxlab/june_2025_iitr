# %%
1. Pick two project from Kaggle
2. Build a neural network (Sequential/Functional API), Train and observe the performance
3.

# %% [raw]
# https://chatgpt.com/share/69ecd58b-7290-83e8-ab16-569814dc3983m

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fashion_mnist = keras.datasets.fashion_mnist

(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

X_train_full = X_train_full / 255.0
X_test = X_test / 255.0

X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.SGD(learning_rate=0.01),
    metrics=["accuracy"]
)

history = model.fit(
    X_train,
    y_train,
    epochs=30,
    validation_data=(X_valid, y_valid)
)

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

predictions = model.predict(X_test[:5])

for i in range(5):
    plt.imshow(X_test[i], cmap="gray")
    plt.title(
        f"Predicted: {class_names[np.argmax(predictions[i])]} | Actual: {class_names[y_test[i]]}"
    )
    plt.axis("off")
    plt.show()
# Out:
# /Users/sandeepgiri/projects/course_repos/june_2025_iitr/.venv/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 985us/step - accuracy: 0.7609 - loss: 0.7189 - val_accuracy: 0.8284 - val_loss: 0.5113
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 823us/step - accuracy: 0.8271 - loss: 0.4955 - val_accuracy: 0.8490 - val_loss: 0.4437
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 827us/step - accuracy: 0.8448 - loss: 0.4474 - val_accuracy: 0.8530 - val_loss: 0.4258
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 844us/step - accuracy: 0.8540 - loss: 0.4199 - val_accuracy: 0.8546 - val_loss: 0.4108
# Epoch 5/30
# ...

# %%
def uniform_distribution(r, shape):
    pass

# Generate 10 random numbers between -2.3 and 2.3
uniform_distribution(2.3, (10,))

# %% [markdown]
# $$
# f(x)=\frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(x-\mu)^2}{2\sigma^2}}
# $$

# %%
# See https://en.wikipedia.org/wiki/Normal_distribution


def normal_distribution(shape, sd):
    pass

# Generate 100 random numbers with normal distribution with sd of approx .5 and mean = 0
data = normal_distribution(shape=(100,), sd=0.5)

# sd(data) == .5

# %%
import tensorflow as tf

# Generate 1000 samples from a standard normal distribution (mean=0, stddev=3.5)
data = tf.random.normal(shape=(100,), mean=0.0, stddev=3.5)

print(data[:10])  # first 10 values
# Out:
# tf.Tensor(
# [-7.6274166  1.1693357 -0.7263779 -2.7842343  0.1477308 -2.6905756
#   0.8802936  3.4342117 -2.7934842  5.5284524], shape=(10,), dtype=float32)

# %%
import numpy as np

# %%
np.std(data)
# Out:
# np.float32(3.180153)

# %% [markdown]
# ## With batch norm

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fashion_mnist = keras.datasets.fashion_mnist

(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

X_train_full = X_train_full / 255.0
X_test = X_test / 255.0

X_valid = X_train_full[:5000]
y_valid = y_train_full[:5000]

X_train = X_train_full[5000:]
y_train = y_train_full[5000:]


model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),

    keras.layers.Dense(300, kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),

    keras.layers.Dense(200, kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),

    keras.layers.Dense(100, kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),

    keras.layers.Dense(50, kernel_initializer="he_normal", use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation("relu"),

    keras.layers.Dense(10, activation="softmax")
])

early_stop = keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True
)
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.SGD(learning_rate=0.01),
    metrics=["accuracy"],
)

history = model.fit(
    X_train,
    y_train,
    epochs=30,
    validation_data=(X_valid, y_valid),
    callbacks=[early_stop]
)

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)

predictions = model.predict(X_test[:5])

for i in range(5):
    plt.imshow(X_test[i], cmap="gray")
    plt.title(
        f"Predicted: {class_names[np.argmax(predictions[i])]} | Actual: {class_names[y_test[i]]}"
    )
    plt.axis("off")
    plt.show()
# Out:
# Epoch 1/30
# /Users/sandeepgiri/projects/course_repos/june_2025_iitr/.venv/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7825 - loss: 0.6757 - val_accuracy: 0.8554 - val_loss: 0.4122
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8470 - loss: 0.4418 - val_accuracy: 0.8766 - val_loss: 0.3584
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8631 - loss: 0.3847 - val_accuracy: 0.8758 - val_loss: 0.3426
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8735 - loss: 0.3544 - val_accuracy: 0.8828 - val_loss: 0.3256
# Epoch 5/30
# ...

# %%
# https://cdn.openai.com/research-covers/language-unsupervised/language_understanding_paper.pdf#page=3.35

# %% [raw]
# # Look at the transfer learning logic. "Reusing Pretrained Layers"
#
# #And build an intuition about the benefit of transfer learning.
#
# We had a model A which never saw shirt / sandals.
#
# We inherited that moel into model B on A
# and then by sight train it was able to distringuish between shirts and sandals.
